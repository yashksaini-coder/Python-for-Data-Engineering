# %%
user = {'name': 'Deepak', 'city':'Indore', 'age':20}
print(user)
# Out:
# {'name': 'Deepak', 'city': 'Indore', 'age': 20}

# %%
print(user['city'])
# Out:
# Indore

# %%
user.get('city')
# Out:
# 'Indore'

# %%
keys = user.keys()
print(keys)
# Out:
# dict_keys(['name', 'city', 'age'])

# %%
values = user.values()
print(values)
# Out:
# dict_values(['Deepak', 'Indore', 20])

# %%
if 'name' in user:
  print('yes')
# Out:
# yes

# %%
user['city'] = 'Mumbai'
print(user)
# Out:
# {'name': 'Deepak', 'city': 'Mumbai', 'age': 20}

# %%
user.update({'mobile':343276432})
print(user)
# Out:
# {'name': 'Deepak', 'city': 'Mumbai', 'age': 20, 'mobile': 343276432}

# %%
user.pop('mobile')
print(user)
# Out:
# {'name': 'Deepak', 'city': 'Mumbai', 'age': 20}

# %%
for x in user.keys():
  print(user[x])
# Out:
# Deepak
# Mumbai
# 20

# %%
new_user = user
new_user.update({'mobile':75984375})
print(user)
# Out:
# {'name': 'Deepak', 'city': 'Mumbai', 'age': 20, 'mobile': 75984375}

# %%
new_user = user.copy()
