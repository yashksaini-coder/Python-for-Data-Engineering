# %%
tasks = {'development', 'testing', 'monitoring'}
print(tasks)
# Out:
# {'development', 'monitoring', 'testing'}

# %%
tasks = {'development', 'testing', 'monitoring', 'testing'}
print(tasks)
# Out:
# {'development', 'monitoring', 'testing'}

# %%
tasks.add('prod deployment')
print(tasks)
# Out:
# {'development', 'monitoring', 'testing', 'prod deployment'}

# %%
new_task = {'unit testing', 'SIT testing'}
tasks.update(new_task)
print(tasks)
# Out:
# {'development', 'unit testing', 'monitoring', 'testing', 'SIT testing', 'prod deployment'}

# %%
tasks.remove('testing')
print(tasks)
# Out:
# {'development', 'unit testing', 'monitoring', 'SIT testing', 'prod deployment'}

# %%
new_task.clear()
print(new_task)
# Out:
# set()
