# %%
import numpy as np

array1 = np.array([[1,2], [3,4]])
array2 = np.array(([5,6], [7,8]))

mul = np.dot(array1, array2)

print(mul)
# Out:
# [[19 22]
#  [43 50]]

# %%
invr = np.linalg.inv(array1)
print(invr)
# Out:
# [[-2.   1. ]
#  [ 1.5 -0.5]]

# %%
eval, evect = np.linalg.eig(array1)

# %%
data = np.array([1,2,3,4,5])
mean  = np.mean(data)
std_dev = np.std(data)

print(mean)
print(std_dev)
# Out:
# 3.0
# 1.4142135623730951

# %%
data2 = np.array([11,12,13,14,15])

cor = np.corrcoef(data, data2)
print(cor)
# Out:
# [[1. 1.]
#  [1. 1.]]

# %%
np.savetxt('Output/output_1.csv', mul, delimiter=',')

# %%
np.save('Output/output_1.npy', mul)
new_matrix = np.load('output.npy')

# %%
import pandas as pd

df = pd.DataFrame(mul)
df.to_excel('Output/output_1.xlsx')
