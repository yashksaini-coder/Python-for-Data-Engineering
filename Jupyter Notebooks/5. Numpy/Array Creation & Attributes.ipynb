# %%
import numpy as np

nums = [1,2,3,4,5]

arrayy1 = np.array(nums)
print(arrayy1)
# Out:
# [1 2 3 4 5]

# %%
zero_array = np.zeros(5)
print(zero_array)
# Out:
# [0. 0. 0. 0. 0.]

# %%
one_array = np.ones(3)
print(one_array)
# Out:
# [1. 1. 1.]

# %%
range_array = np.arange(1,10,2)
print(range_array)
# Out:
# [1 3 5 7 9]

# %%
random_array = np.random.randint(1,100,5)
print(random_array)
# Out:
# [73 55 69 63 90]

# %%
random_matrix = np.random.rand(3,3)
print(random_matrix)
# Out:
# [[0.45174604 0.28663886 0.58346831]
#  [0.86538559 0.59980041 0.15135816]
#  [0.31841874 0.36134142 0.87307176]]

# %%
shape = range_array.shape
print(shape)
# Out:
# (5,)

# %%
size = range_array.size
print(size)
# Out:
# 5

# %%
dtype = range_array.dtype
print(dtype)
# Out:
# int32

# %%
print(range_array.ndim)
# Out:
# 1
