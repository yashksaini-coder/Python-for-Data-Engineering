# %%
import math

# %%
print(math.sqrt(16))
# Out:
# 4.0

# %%
# !pip install pandas

# %%
import pandas as pd
data = {'name': ['John', 'Anna', 'Peter'], 'Age':[20,30,40]}
df = pd.DataFrame(data)
print(df)
# Out:
#     name  Age
# 0   John   20
# 1   Anna   30
# 2  Peter   40
